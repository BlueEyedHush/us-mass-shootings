# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from pie_on_map import plotit

cols = ['gender_dedup', 'races_dedup', 'missues_dedup']

# %%
for c in cols:
    plotit(c)
# Out:
# 3
# 10
# 2
