# %%
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
from data_proc import ms_ds
# Out:
# data_proc.py:106: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   split_date = ms_cfilter['Date'].str.extract('^(?P<month>[0-9]+)/(?P<day>[0-9]+)/(?P<year>[0-9]+)$')

# %%
ms_ds
# Out:
#       S#                                       Title  \
# 0      1               Las Vegas Strip mass shooting
# 1      2                  San Francisco UPS shooting
# 2      3           Pennsylvania supermarket shooting
# 3      4        Florida awning manufacturer shooting
# 4      5            Rural Ohio nursing home shooting
# 5      6                    Fresno downtown shooting
# 6      7            Fort Lauderdale airport shooting
# 7      8                       Cascade Mall shooting
# 8      9                 Baton Rouge police shooting
# 9     10                      Dallas police shooting
# 10    11                  Orlando nightclub massacre
# 11    12                       Ferguson, MO Drive by
# 12    13              Forestville, Maryland Drive-by
# 13    14                          Halifax County, VA
# 14    15            Tire-Slashing revenge escalation
# 15    16                  Chicago Rap video Shootout
# 16    17                 Texas family murder-suicide
# 17    18             Alabama highway random shooting
# 18    19                    Long Beach Street murder
# 19    20        Albuquerque, NM House party shooting
# 20    21            Memphis, TN gas station shooting
# 21    22         Chicago Birthday Party Bus Shooting
# 22    23  Albuquerque, NM Family restaurant shooting
# 23    24                          Richmond, Virginia
# 24    25                   Louisburg, North Carolina
# 25    26                     Lawrenceburg, Tennessee
# 26    27         Greenhill, AL Family murder-suicide
# 27    28        Sherman, Texas Family Murder-Suicide
# 28    29        Louisville, KY Family Murder-Suicide
# 29    30                         Plantation, Florida
# ..   ...                                         ...
# 290  291                 Cleveland Elementary School
# 291  292            New Orleans Downtown Post Office
# 292  293                   Oakland Elementary School
# 293  294      Comet Auto Parts and Montefiore School
# 294  295             Hubbard Woods Elementary School
# 295  296    Electromagnetic Systems Laboratory (ESL)
# 296  297                   Pinellas Park High School
# 297  298                   Palm Bay Shopping Centers
# 298  299                   Fergus County High School
# 299  300             Post office in Edmond, Oklahoma
# 300  301                  New York Technical College
# 301  302                         Atlanta Post Office
# 302  303                  Goddard Junior High School
# 303  304         McDonald's restaurant in San Ysidro
# 304  305                      Ianni's Club in Dallas
# 305  306               49th Street Elementary School
# 306  307                        Johnston Post Office
# 307  308                     Wah Mee Club in Seattle
# 308  309                       Welding shop in Miami
# 309  310                          Valley High School
# 310  311                University of South Carolina
# 311  312          Grover Cleveland Elementary School
# 312  313                         Cal State Fullerton
# 313  314        Los Angeles Computer Learning Center
# 314  315                           Olean High School
# 315  316              Clara Barton Elementary School
# 316  317                New Orleans Police Shootings
# 317  318                         St. Aloysius Church
# 318  319                  Rose-Mar College of Beauty
# 319  320               University of Texas at Austin
#
#                                                Summary  Fatalities  Injured  \
# 0                                                  NaN          58      527
# 1    Jimmy Lam, 38, fatally shot three coworkers an...           3        2
# 2    Randy Stair, a 24-year-old worker at Weis groc...           3        0
# 315  On January 17, 1974, a 14-year-old student ent...           1        3
# 316  On New Year's Eve in 1972, a 23-year-old ex-Na...          10       13
# 317  On November 11, 1971, a former MIT student ent...           2        4
# 318  On November 12, 1966, an 18-year-old high scho...           5        1
# 319  On August 1, 1966, a 25-year-old engineering s...          17       32
#
#      Total victims   Latitude   Longitude gender_dedup missues_dedup  \
# 0              585  36.181271 -115.134132         male           NaN
# 1                5        NaN         NaN         male           yes
# 2                3        NaN         NaN         male           NaN
# 3                5        NaN         NaN         male           NaN
# 4                3        NaN         NaN         male           yes
# 5                3        NaN         NaN         male           NaN
# 6               11        NaN         NaN         male           yes
# 7                5        NaN         NaN         male           yes
# 8                6        NaN         NaN         male           yes
# 9               16        NaN         NaN         male           NaN
# 10             102        NaN         NaN         male           NaN
# 11               4  38.744217  -90.305391          NaN           NaN
# 12               5  38.845113  -76.874972          NaN           NaN
# 13               6  36.765971  -78.928344         male           NaN
# 14               4  39.290385  -76.612189         male           NaN
# 15               5  41.878114  -87.629798          NaN           NaN
# 16               4  29.785785  -95.824396         male           NaN
# 17               4  34.162040  -86.475543         male           yes
# 18               4  33.770050 -118.193739          NaN           NaN
# 19               4  35.085334 -106.605553         male           NaN
# 20               4  35.149534  -90.048980          NaN           NaN
# 21               5  41.878114  -87.629798          NaN           NaN
# 22               3  35.085334 -106.605553         male           NaN
# 23               3  37.540725  -77.436048         male           NaN
# 24               3  36.099039  -78.301106         male           NaN
# 25               3  35.242302  -87.334739         male           NaN
# 26               3  34.759257  -86.602493         male           yes
# 27               3  33.635662  -96.608880         male           NaN
# 28               3  38.252665  -85.758456         male           yes
# 29               5  26.127586  -80.233104          NaN           NaN
# ..             ...        ...         ...          ...           ...
# 290             35  37.966318 -121.301877         male           yes
# 291              4  30.068724  -89.931474         male           NaN
# 292             11  34.192895  -82.153555         male           yes
# 293              6  41.839280  -87.688181         male            no
# 294              8  42.106488  -87.742111       female           yes
# 295             11  37.383443 -122.025619         male           yes
# 296              3  27.848871  -82.710580         male            no
# 297             20  27.983890  -80.666627         male           yes
# 298              4  47.037407 -109.484492         male           yes
# 299             20  35.668892  -97.414388         male           yes
# 300              5  40.679276  -73.939513         male           yes
# 301              3  33.762997  -84.423133         male           yes
# 302              4  37.671294  -97.550705         male           yes
# 303             40  32.555556 -117.047656         male           yes
# 304              7  32.794806  -96.766311         male           yes
# 305             14  34.176221 -118.539954         male           yes
# 306              4  33.832729  -81.805158         male           yes
# 307             14  47.621996 -122.323646         male           NaN
# 308             11  25.796539  -80.208404         male           yes
# 309              3  36.189319 -115.326487         male           yes
# 310              7  34.050988  -80.820775         male           NaN
# 311             11  32.863573 -117.128163       female           yes
# 312              9  33.884042 -117.927850         male           yes
# 313              8  34.176221 -118.539954         male           NaN
# 314             10  42.081854  -78.432139         male            no
# 315              4  41.839280  -87.688181         male           yes
# 316             22  30.068724  -89.931474         male           yes
# 317              5  47.673674 -117.415984         male           yes
# 318              6  33.422687 -111.816320         male           yes
# 319             48  30.198887  -97.844159         male           yes
#
#     races_dedup      state_full  month  day  year
# 0         white          nevada     10    1  2017
# 1         asian      california      6   14  2017
# 2         white     pensylvania      6    7  2017
# 3           NaN         florida      6    5  2017
# 4         white            ohio      5   12  2017
# 5         black      california      4   18  2017
# 6        latino         florida      1    6  2017
# 7           NaN      washington      9   23  2016
# 8         black       louisiana      7   17  2016
# 9         black           texas      7    7  2016
# 10        other         florida      6   12  2016
# 11          NaN        missouri      4   29  2016
# 12          NaN             NaN      4   26  2016
# 13        black             NaN      4   24  2016
# 14        black             NaN      4   21  2016
# 15          NaN             NaN      4   19  2016
# 16        white             NaN      4   19  2016
# 17        white             NaN      4   19  2016
# 18          NaN             NaN      4   18  2016
# 19        white             NaN      4    9  2016
# 20          NaN             NaN      4    9  2016
# 21          NaN             NaN      4    7  2016
# 22        asian             NaN      4    1  2016
# 23        black        virginia      3   31  2016
# 24        black  north carolina      3   26  2016
# 25          NaN       tennessee      3   25  2016
# 26        white             NaN      3   25  2016
# 27          NaN           texas      3   21  2016
# 28        white        kentucky      3   20  2016
# 29          NaN         florida      3   19  2016
# ..          ...             ...    ...  ...   ...
# 290       white      california      1   17  1989
# 291         NaN       louisiana     12   14  1988
# 292       white  south carolina      9   26  1988
# 293       black        illinois      9   22  1988
# 294       white        illinois      5   20  1988
# 295       white      california      2   16  1988
# 296       white         florida      2   11  1988
# 297       white         florida      4   23  1987
# 298       white         montana     12    4  1986
# 299       white        oklahoma      8   20  1986
# 300       black        new york      8   12  1986
# 301       black         georgia      3    6  1985
# 302       white          kansas      1   21  1985
# 303       white      california      7   18  1984
# 304       white           texas      6   29  1984
# 305       black      california      2   24  1984
# 306       white  south carolina      8   19  1983
# 307       asian      washington      2   18  1983
# 308       white         florida      8   20  1982
# 309       white          nevada      3   19  1982
# 310       black  south carolina     10    6  1979
# 311       white      california      1   29  1979
# 312       white      california      7   12  1976
# 313       white      california      2   19  1976
# 314       white        new york     12   30  1974
# 315         NaN        illinois      1   17  1974
# 316       black       louisiana     12   31  1972
# 317       white      washington     11   11  1971
# 318       white         arizona     11   12  1966
# 319       white           texas      8    1  1966
#
# [320 rows x 15 columns]

# %%
column = 'gender_dedup'
state = 'california'

vcnt = ms_ds.groupby('state_full').get_group(state)[column].value_counts()
vcnt.sort_index()
rel_vcnt = vcnt/vcnt.sum()

for k,v in rel_vcnt.iteritems():
    print "k {}, v {}".format(k, v)
# Out:
# k male, v 0.838709677419
# k female, v 0.0967741935484
# k male/female, v 0.0645161290323

# %%
ms_ds.sort_index()
uvals = ms_ds[column].value_counts().index
for k in uvals:
    print k
# Out:
# male
# female
# male/female

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl # optional (here)
import matplotlib.pyplot as plt

from ipywidgets import widgets, interactive

# %%
from io import StringIO

testdata=StringIO(u"""Year,Sex,Area,Count
2015,W,Dhaka,6
2015,M,Dhaka,3
2015,W,Khulna,1
2015,M,Khulna,8
2014,M,Dhaka,13
2014,W,Dhaka,20
2014,M,Khulna,9
2014,W,Khulna,6
2013,W,Dhaka,11
2013,M,Dhaka,2
2013,W,Khulna,8
2013,M,Khulna,5
2012,M,Dhaka,12
2012,W,Dhaka,4
2012,W,Khulna,7
2012,M,Khulna,1
    """)

df = pd.read_csv(testdata, sep=",")

# %%
# Create two bounded text box that allow only numbers between the min year (2012) and the max year (2015)
start_year = widgets.BoundedFloatText(
    value=df.Year.min(),
    min=df.Year.min(),
    max=df.Year.max(),
    step=1,
    description='Start Year:',
    disabled=False,
    color='black'
)
end_year = widgets.BoundedFloatText(
    value=df.Year.max(),
    min=df.Year.min(),
    max=df.Year.max(),
    step=1,
    description='End Year:',
    disabled=False,
    color='black'
)

# Make a dropdown to select the Area, or "All"
area = widgets.Dropdown(
    options=['All'] + list(df['Area'].unique()),
    value='All',
    description='Area:',
)

def plotit(area, start_year, end_year):
    """
    Filters and plot the dataframe as a stacked bar chart of count of Male versus Women

    Args:
    -----
        * area (str): the area to filter on, or "All" to display all Areas

        * start_year, end_year (int, as float): the start and ends years, inclusive

        Note: the dataframe to plot is globally defined here as `df`

    Returns:
    --------
        A matplotlib stacked bar chart

    """
    if start_year > end_year:
        print("You must select a start year that is prior to end year")
    else:
        df2 = df.copy()
        if area != 'All':
            df2 = df2[df2.Area == area]

        # Filter between min and max years (inclusive)
        df2 = df2[(df2.Year >= start_year) & (df2.Year <= end_year)]


        # Plot it (only if there's data to plot)
        if len(df2) > 0:
            df2.groupby(['Year', 'Sex']).sum()['Count'].unstack().plot(kind='bar', stacked=True, title="Area = {}".format(area))
            plt.show();
        else:
            print("No data to show for current selection")

# %%
interactive(plotit, area=area, start_year=start_year, end_year=end_year)
# Out:
# interactive(children=(Dropdown(description=u'Area:', options=('All', 'Dhaka', 'Khulna'), value='All'), BoundedFloatText(value=2012.0, description=u'Start Year:', max=2015.0, min=2012.0, step=1.0), BoundedFloatText(value=2015.0, description=u'End Year:', max=2015.0, min=2012.0, step=1.0), Output()), _dom_classes=('widget-interact',))

# %%
ms_ds.groupby('state_full').sum()
# Out:
#                    S#  Fatalities  Injured  Total victims    Latitude  \
# state_full
# alabama          1403          29       25             55  294.042915
# alaska            258           2        2              4   60.790539
# arizona          1908          44       26             65  366.281073
# arkansas          457           5       11             18   70.902297
# california       6565         176      211            375  946.166056
# colorado         1078          43      109            148  197.679976
# connecticut       621          42        4             44  124.874849
# florida          2950         119      138            252  475.753168
# georgia          2043          40       47             81  436.729588
# hawaii            243           7        0              7   21.325512
# idaho             142           3        1              4   46.730595
# illinois         1965          36       45             75  372.749676
# indiana           119           0        5              5   39.777255
# iowa              284           6        1              6   41.655894
# kansas            441          13       31             43  114.922147
# kentucky         1050          27       18             42  190.378869
